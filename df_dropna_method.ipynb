# %% [markdown]
# <a href="https://colab.research.google.com/github/JavZon/Data-processing-and-preparation/blob/main/df_dropna_method.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import sqlite3 as sql

# %%
link ='https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/automobile_data_nan.csv'
df=pd.read_csv(link, index_col=0)
df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         NaN             21.0  13495.0
# 1                 four       111.0             21.0  16500.0
# 2                  six       154.0              NaN  16500.0
# 3                 four       102.0             24.0  13950.0
# 4                 five         NaN              NaN  17450.0

# %%
df.isnull().sum()
# Out:
# company              0
# body-style           0
# wheel-base          15
# length              13
# engine-type         12
# num-of-cylinders     0
# horsepower          16
# average-mileage     15
# price                3
# dtype: int64

# %%
df.dropna()
# Out:
#           company   body-style  wheel-base  length engine-type  \
# index
# 3            audi        sedan        99.8   176.6         ohc
# 5            audi        sedan        99.8   177.3         ohc
# 6            audi        wagon       105.8   192.7         ohc
# 17      chevrolet    hatchback        94.5   155.9         ohc
# 19          dodge    hatchback        93.7   157.3         ohc
# 28          honda        sedan        96.5   175.4         ohc
# 34         jaguar        sedan       113.0   199.6        dohc
# 37          mazda    hatchback        93.1   159.1         ohc
# 38          mazda    hatchback        93.1   159.1         ohc
# 54         nissan        sedan        94.5   165.3         ohc
# 56         nissan        wagon        94.5   170.2         ohc
# 62        porsche  convertible        89.5   168.9        ohcf
# 69         toyota        wagon        95.7   169.7         ohc
# 81     volkswagen        sedan        97.3   171.7         ohc
#
# ...

# %%
len(df.dropna())
# Out:
# 14

# %%
data = {'A': [1, 2, np.nan, 4],
        'B': [np.nan, 5, 6, 7],
        'C':[np.nan,np.nan,np.nan,np.nan],
        'D':[21,8,13,9]}
df2 = pd.DataFrame(data)
df2
# Out:
#      A    B   C   D
# 0  1.0  NaN NaN  21
# 1  2.0  5.0 NaN   8
# 2  NaN  6.0 NaN  13
# 3  4.0  7.0 NaN   9

# %%
df2.dropna()
# Out:
# Empty DataFrame
# Columns: [A, B, C, D]
# Index: []

# %%
df2.dropna(axis=1)
# Out:
#     D
# 0  21
# 1   8
# 2  13
# 3   9

# %%
df.dropna(axis=1, thresh=49)
# chegarani bildiradi, ya'ni column yoki rowdan bizga minimum nechta qiymat saqlagan holda,
# qolgan NaN qiymatlarni o'chirib yuborishni anlatadi
# Out:
#            company   body-style engine-type num-of-cylinders    price
# index
# 0      alfa-romero  convertible        dohc             four  13495.0
# 1      alfa-romero  convertible        dohc             four  16500.0
# 2      alfa-romero    hatchback        ohcv              six  16500.0
# 3             audi        sedan         ohc             four  13950.0
# 4             audi        sedan         ohc             five  17450.0
# ...            ...          ...         ...              ...      ...
# 81      volkswagen        sedan         ohc             four   7975.0
# 82      volkswagen        sedan         NaN             four   7995.0
# 86      volkswagen        sedan         ohc             four   9995.0
# 87           volvo        sedan         NaN             four  12940.0
# 88           volvo        wagon         ohc             four  13415.0
#
# [61 rows x 5 columns]

# %%
df2
# Out:
#      A    B     C   D
# 0  1.0  NaN  None  21
# 1  2.0  5.0  None   8
# 2  NaN  6.0  None  13
# 3  4.0  7.0  None   9

# %%
df2.dropna(subset='A')
# Out:
#      A    B     C   D
# 0  1.0  NaN  None  21
# 1  2.0  5.0  None   8
# 3  4.0  7.0  None   9

# %%
df2.dropna(axis=1, how='all')
# Out:
#      A    B   D
# 0  1.0  NaN  21
# 1  2.0  5.0   8
# 2  NaN  6.0  13
# 3  4.0  7.0   9

# %%
df2
# Out:
#      A    B   C   D
# 0  1.0  NaN NaN  21
# 1  2.0  5.0 NaN   8
# 2  NaN  6.0 NaN  13
# 3  4.0  7.0 NaN   9

# %%
df2.dropna(subset='A')
# Out:
#      A    B   C   D
# 0  1.0  NaN NaN  21
# 1  2.0  5.0 NaN   8
# 3  4.0  7.0 NaN   9

# %%
df.size
# Out:
# 549
