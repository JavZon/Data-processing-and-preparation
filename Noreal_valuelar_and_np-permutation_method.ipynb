# %% [markdown]
# <a href="https://colab.research.google.com/github/JavZon/Data-processing-and-preparation/blob/main/Noreal_valuelar_and_np-permutation_method.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
url='https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/MOCK_USER_DATA.csv'
df=pd.read_csv(url, index_col='id')
df.head()
# Out:
#    first_name   last_name                           email       gender   age
# id
# 1     Dorothy     Verryan               dverryan0@who.int   Non-binary     1
# 2     Pietrek     Scanlin          pscanlin1@yolasite.com         Male    91
# 3      Lilith    Sarjeant  lsarjeant2@creativecommons.org  Genderfluid  1233
# 4        Knox  Cunningham    kcunningham3@yellowpages.com  Genderfluid     6
# 5    Mohammed  Habbershon    mhabbershon4@sourceforge.net       Female    48

# %%
df
# Out:
#     first_name   last_name                           email       gender   age
# id
# 1      Dorothy     Verryan               dverryan0@who.int   Non-binary     1
# 2      Pietrek     Scanlin          pscanlin1@yolasite.com         Male    91
# 3       Lilith    Sarjeant  lsarjeant2@creativecommons.org  Genderfluid  1233
# 4         Knox  Cunningham    kcunningham3@yellowpages.com  Genderfluid     6
# 5     Mohammed  Habbershon    mhabbershon4@sourceforge.net       Female    48
# ..         ...         ...                             ...          ...   ...
# 96        Baxy       Marcu        bmarcu2n@list-manage.com      Agender    64
# 97      Kattie     Claxson          kclaxson2o@booking.com       Female    18
# 98        Clem     Fullerd  cfullerd2p@creativecommons.org     Bigender    55
# 99   Desdemona     Jurasek        djurasek2q@aboutads.info  Genderfluid    46
# 100      Mable     Toffano          mtoffano2r@myspace.com     Bigender   233
#
# [100 rows x 5 columns]

# %%
df['gender'].unique()
# Out:
# array(['Non-binary', 'Male', 'Genderfluid', 'Female', 'Agender',
#        'Bigender', 'Polygender', 'Genderqueer'], dtype=object)

# %%
df['gender'].value_counts()
# Out:
# Male           21
# Genderfluid    14
# Bigender       13
# Female         12
# Genderqueer    11
# Non-binary     10
# Polygender     10
# Agender         9
# Name: gender, dtype: int64

# %%
mask=(df['gender']=='Male')|(df['gender']=='Female')
df=df[mask]
df
# Out:
#    first_name     last_name                         email  gender  age
# id
# 2     Pietrek       Scanlin        pscanlin1@yolasite.com    Male   91
# 5    Mohammed    Habbershon  mhabbershon4@sourceforge.net  Female   48
# 10      David      Meredyth    dmeredyth9@telegraph.co.uk  Female   68
# 12  Raffaello     Firminger     rfirmingerb@bloomberg.com  Female   74
# 17      Byram   Martynikhin     bmartynikhing@jiathis.com    Male   40
# 19      Luisa     Bradborne          lbradbornei@fema.gov  Female  -75
# 22        Ray         Padly           rpadlyl@twitpic.com    Male   85
# 26   Ephrayim    Westmacott         ewestmacottp@ning.com    Male   77
# 29      Biron      Acklands        backlandss@comsenz.com    Male   13
# 33   Ebenezer       Greeves         egreevesw@myspace.com    Male  -26
# 34     Brooks          Vose             bvosex@amazon.com  Female   34
# 36        Axe       Arundel           aarundelz@yahoo.com  Female   14
# ...

# %%
df['gender'].value_counts()
# Out:
# Male      21
# Female    12
# Name: gender, dtype: int64

# %%
df['age'].unique()
# Out:
# array([ 91,  48,  68,  74,  40, -75,  85,  77,  13, -26,  34,  14,  23,
#         66, 344,   1,  94, 100,  92,  60,  47,  69,  12,  98,   3,  93,
#        -69,  18])

# %%
df['age']=df['age'].map(lambda x : np.abs(x) )
df
# Out:
#    first_name     last_name                         email  gender  age
# id
# 2     Pietrek       Scanlin        pscanlin1@yolasite.com    Male   91
# 5    Mohammed    Habbershon  mhabbershon4@sourceforge.net  Female   48
# 10      David      Meredyth    dmeredyth9@telegraph.co.uk  Female   68
# 12  Raffaello     Firminger     rfirmingerb@bloomberg.com  Female   74
# 17      Byram   Martynikhin     bmartynikhing@jiathis.com    Male   40
# 19      Luisa     Bradborne          lbradbornei@fema.gov  Female   75
# 22        Ray         Padly           rpadlyl@twitpic.com    Male   85
# 26   Ephrayim    Westmacott         ewestmacottp@ning.com    Male   77
# 29      Biron      Acklands        backlandss@comsenz.com    Male   13
# 33   Ebenezer       Greeves         egreevesw@myspace.com    Male   26
# 34     Brooks          Vose             bvosex@amazon.com  Female   34
# 36        Axe       Arundel           aarundelz@yahoo.com  Female   14
# ...

# %%
# 1-usul
#mask=df['age']<123
#df=df[mask]
df=df[df['age'] < 123]
df['age']=df['age'].astype('Int64')
df
# Out:
# <ipython-input-10-5054e7c773b8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['age']=df['age'].astype('Int64')
#    first_name     last_name                         email  gender  age
# id
# 2     Pietrek       Scanlin        pscanlin1@yolasite.com    Male   91
# 5    Mohammed    Habbershon  mhabbershon4@sourceforge.net  Female   48
# 10      David      Meredyth    dmeredyth9@telegraph.co.uk  Female   68
# 12  Raffaello     Firminger     rfirmingerb@bloomberg.com  Female   74
# 17      Byram   Martynikhin     bmartynikhing@jiathis.com    Male   40
# 19      Luisa     Bradborne          lbradbornei@fema.gov  Female   75
# 22        Ray         Padly           rpadlyl@twitpic.com    Male   85
# ...

# %%
 # 2-usul
#df['age']=df['age'].apply(lambda x : x if x<123 else None)

# %%
df.describe()
# Out:
#              age
# count       32.0
# mean      56.125
# std    32.201733
# min          1.0
# 25%        25.25
# 50%         67.0
# 75%         79.0
# max        100.0

# %%
df.shape
# Out:
# (32, 5)

# %%
randlist=np.random.permutation(32)
randlist
# Out:
# array([14, 22, 13, 28,  9, 11,  0, 18, 21, 19,  3, 16, 29, 10,  7,  6,  5,
#        17, 12, 20, 25,  8,  2, 15, 24, 30, 26, 27,  4, 31, 23,  1])

# %%
df.take(randlist)
# Out:
#    first_name     last_name                         email  gender  age
# id
# 58     Brynna        Worsom              bworsom1l@wp.com    Male   66
# 76      Misty         Blanc         mblanc23@amazon.co.jp    Male   74
# 46     Alvira  Stollsteiner     astollsteiner19@mysql.com    Male   66
# 90  Zachariah         Meins          zmeins2h@weather.com    Male   69
# 33   Ebenezer       Greeves         egreevesw@myspace.com    Male   26
# 36        Axe       Arundel           aarundelz@yahoo.com  Female   14
# 2     Pietrek       Scanlin        pscanlin1@yolasite.com    Male   91
# 67     Bunnie        Ozanne      bozanne1u@whitehouse.gov    Male   92
# 74      Curry    Smalecombe  csmalecombe21@washington.edu    Male   69
# 70      Ambur        Aickin           aaickin1x@about.com    Male   60
# 12  Raffaello     Firminger     rfirmingerb@bloomberg.com  Female   74
# 62     Kennan         Visco          kvisco1p@jiathis.com  Female   94
# ...

# %%
df.shape
# Out:
# (32, 5)

# %%
np.random.permutation(6)
# Out:
# array([2, 1, 3, 5, 0, 4])

# %%
df.iloc[randlist]
# Out:
#    first_name     last_name                         email  gender  age
# id
# 58     Brynna        Worsom              bworsom1l@wp.com    Male   66
# 76      Misty         Blanc         mblanc23@amazon.co.jp    Male   74
# 46     Alvira  Stollsteiner     astollsteiner19@mysql.com    Male   66
# 90  Zachariah         Meins          zmeins2h@weather.com    Male   69
# 33   Ebenezer       Greeves         egreevesw@myspace.com    Male   26
# 36        Axe       Arundel           aarundelz@yahoo.com  Female   14
# 2     Pietrek       Scanlin        pscanlin1@yolasite.com    Male   91
# 67     Bunnie        Ozanne      bozanne1u@whitehouse.gov    Male   92
# 74      Curry    Smalecombe  csmalecombe21@washington.edu    Male   69
# 70      Ambur        Aickin           aaickin1x@about.com    Male   60
# 12  Raffaello     Firminger     rfirmingerb@bloomberg.com  Female   74
# 62     Kennan         Visco          kvisco1p@jiathis.com  Female   94
# ...
